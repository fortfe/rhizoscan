# %% [markdown]
# # RhizoScan Pipeline

# %% [markdown]
# This pipeline is a step by step pipeline

# %% [markdown]
# ## Common import

# %%
# %pylab notebook
from matplotlib import pyplot as plt
from IPython.display import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## RhizoScan Import

# %%
from rhizoscan import get_data_path
from rhizoscan.root.pipeline import load_image, detect_petri_plate, compute_graph, compute_tree
from rhizoscan.root.pipeline.arabidopsis import segment_image, detect_leaves
from rhizoscan.root.graph.mtg import tree_to_mtg

# %% [markdown]
# ## RSA Image

# %%
image_filename = get_data_path('pipeline/arabido.png')
Image(image_filename)

# %% [markdown]
# ### Load Image

# %%
image = load_image(image_filename)
imshow(image)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Detect features (Petri plate)

# %%
pmask, px_scale, hull = detect_petri_plate(image,border_width=25, plate_size=120, fg_smooth=1)
imshow(pmask==0)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Image Segmentation

# %%
rmask, bbox = segment_image(image,pmask,root_max_radius=5)
imshow(rmask)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Detect leaves and seed

# %%
seed_map = detect_leaves(rmask, image, bbox, plant_number=2, leaf_bbox=[0,0,1,.4])
#imshow(seed_map)
imshow(seed_map)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-f3d9480f1555> in <module>()
# ----> 1 seed_map = detect_leaves(rmask, image, bbox, plant_number=2, leaf_bbox=[0,0,1,.4])
#       2 #imshow(seed_map)
#       3 imshow(seed_map)
#
# c:\users\fortfer\rhizoscan\src\rhizoscan\root\pipeline\arabidopsis.pyc in detect_leaves(rmask, image, bbox, plant_number, root_min_radius, leaf_bbox, sort)
#     117 @_node('seed_map', OA_hide=['sort'])
#     118 def detect_leaves(rmask, image, bbox, plant_number=1, root_min_radius=3, leaf_bbox=[.05,.05,.95,.2], sort=True):
# --> 119     seed_map = _detect_leaves(mask=rmask, image=image[bbox], leaf_number=plant_number, root_radius=root_min_radius, leaf_bbox=leaf_bbox, sort=sort) ##
#     120     seed_map = seed_map.view(_Image)
#     121     seed_map.set_serializer(pil_format='PNG', ser_dtype='uint8', ser_scale=255/plant_number)
#
# c:\users\fortfer\rhizoscan\src\rhizoscan\root\image\seed.pyc in detect_leaves(mask, image, leaf_number, root_radius, leaf_bbox, sort)
#      37
#      38     # segment mask
# ---> 39     label, N, radius, dmap = blob_cluster(mask)
#      40
#      41     # classify leaf area
#
# c:\users\fortfer\rhizoscan\src\rhizoscan\root\image\seed.pyc in blob_cluster(mask, dmin)
#     137     *** require skimage:  skimage.morphology.watershed ***
#     138     """
# --> 139     from skimage.morphology import watershed
#     140     dmap = _nd.distance_transform_edt(mask)
#     141     dmax = _local_min(-dmap, footprint=1+2*dmin)*(dmap>dmin)
#
# C:\Users\FORTFER\Miniconda3\envs\rhizo\lib\site-packages\skimage\__init__.py in <module>()
#     156     except ImportError as e:
#     157         _raise_build_error(e)
# --> 158     from .util.dtype import *
#     159
#     160
#
# C:\Users\FORTFER\Miniconda3\envs\rhizo\lib\site-packages\skimage\util\__init__.py in <module>()
#       3 from .shape import view_as_blocks, view_as_windows
#       4 from .noise import random_noise
# ----> 5 from .apply_parallel import apply_parallel
#       6
#       7 from .arraycrop import crop
#
# C:\Users\FORTFER\Miniconda3\envs\rhizo\lib\site-packages\skimage\util\apply_parallel.py in <module>()
#       6
#       7 try:
# ----> 8     import dask.array as da
#       9     dask_available = True
#      10 except ImportError:
#
# C:\Users\FORTFER\Miniconda3\envs\rhizo\lib\site-packages\dask\array\__init__.py in <module>()
#       3 try:
#       4     from .blockwise import blockwise, atop
# ----> 5     from .core import (Array, block, concatenate, stack, from_array, store,
#       6                        map_blocks, to_hdf5, to_npy_stack, from_npy_stack,
#       7                        from_delayed, asarray, asanyarray, PerformanceWarning,
#
# C:\Users\FORTFER\Miniconda3\envs\rhizo\lib\site-packages\dask\array\core.py in <module>()
#      27 import numpy as np
#      28
# ---> 29 from . import chunk
#      30 from .. import config
#      31 from ..base import (DaskMethodsMixin, tokenize, dont_optimize,
#
# C:\Users\FORTFER\Miniconda3\envs\rhizo\lib\site-packages\dask\array\chunk.py in <module>()
#      71     from numpy import nancumprod, nancumsum
#      72 except ImportError:  # pragma: no cover
# ---> 73     nancumprod = npcompat.nancumprod
#      74     nancumsum = npcompat.nancumsum
#      75
#
# AttributeError: 'module' object has no attribute 'nancumprod'

# %%
from dask.array import npcompat
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-54e42a038658> in <module>()
# ----> 1 from dask.array import npcompat
#
# C:\Users\FORTFER\Miniconda3\envs\rhizo\lib\site-packages\dask\array\__init__.py in <module>()
#      60            "  conda install dask                 # either conda install\n"
#      61            "  pip install dask[array] --upgrade  # or pip install")
# ---> 62     raise ImportError(str(e) + '\n\n' + msg)
#
# ImportError: cannot import name numpy_compat
#
# Dask array requirements are not installed.
#
# Please either conda or pip install as follows:
#
#   conda install dask                 # either conda install
#   pip install dask[array] --upgrade  # or pip install

# %% [markdown]
# ### Compute the graph corresponding to the RSA

# %%
graph = compute_graph(rmask,seed_map,bbox)
graph.plot(linewidth=4)

# %% [markdown]
# ### Extract a tree from the graph

# %%
tree = compute_tree(graph, px_scale=px_scale)
tree.plot(linewidth=4)
# Out:
# /home/artzet_s/PycharmProjects/Rhizo/rhizoscan/src/rhizoscan/root/graph/nsa.py:307: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif ids=='auto': self.setdefault('id',_np.arange(self.number()))
# /home/artzet_s/PycharmProjects/Rhizo/rhizoscan/src/rhizoscan/root/graph/__init__.py:196: RuntimeWarning: divide by zero encountered in divide
#   shifty  = _np.arange(len(axe_node))/ms % (2*ms+1) - ms

# %% [markdown]
# ### Save the RSA into an MTG

# %%
g = rsa = tree_to_mtg(tree)
g.display()
# Out:
# MTG : nb_vertices=54, nb_scales=4
# /P			(id=1)
# ^/A			(id=3)
# ^/S			(id=4)
# ^<S			(id=5)
# ^<S			(id=6)
# 	+A			(id=38)
# 	^/S			(id=39)
# 	^<S			(id=40)
# 	^<S			(id=41)
# ^<S			(id=7)
# ^<S			(id=8)
# 	+A			(id=42)
# 	^/S			(id=43)
# 	^<S			(id=44)
# 	^<S			(id=45)
# ^<S			(id=9)
# ^<S			(id=10)
# ^<S			(id=11)
# ^<S			(id=12)
# 	+A			(id=50)
# 	^/S			(id=51)
# 	^<S			(id=52)
# 	^<S			(id=53)
# ^<S			(id=13)
# ^<S			(id=14)
# ^<S			(id=15)
# /P			(id=2)
# ^/A			(id=16)
# ^/S			(id=17)
# ^<S			(id=18)
# ^<S			(id=19)
# ^<S			(id=20)
# ^<S			(id=21)
# 	+A			(id=31)
# 	^/S			(id=32)
# 	^<S			(id=33)
# 	^<S			(id=34)
# 	^<S			(id=35)
# 	^<S			(id=36)
# 	^<S			(id=37)
# ^<S			(id=22)
# ^<S			(id=23)
# ^<S			(id=24)
# 	+A			(id=46)
# 	^/S			(id=47)
# 	^<S			(id=48)
# 	^<S			(id=49)
# ^<S			(id=25)
# ^<S			(id=26)
# ^<S			(id=27)
# ^<S			(id=28)
# ^<S			(id=29)
# ^<S			(id=30)
